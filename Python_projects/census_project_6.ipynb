# %% [markdown]
# ## India cesnsus 2011 dataset

# %% [markdown]
# #### This data is about total population, demography, literacy, districts, states, workers, religion, education, age from India

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
file = os.path.join(os.getcwd(),'raw_data/6. India Census 2011.csv')
df = pd.read_csv(file)
df_copy = df.copy()

# %% [markdown]
# #### Data exploratory

# %%
df_copy.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df_copy.dtypes
# Out:
# District_code            int64
# State_name              object
# District_name           object
# Population               int64
# Male                     int64
# Female                   int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
df_copy.shape
# Out:
# (640, 25)

# %%
df_copy.describe()
# Out:
#        District_code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#             Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# count  6.400000e+02  6.400000e+02    6.400000e+02        6.400000e+02
# mean   7.529514e+05  5.186561e+05    2.342953e+05        1.856387e+05
# ...

# %% [markdown]
# #### 1 How will you hide the indexes of the dataframe

# %%
df_copy.head().style.hide_index()
# Out:
# /tmp/ipykernel_527/1104393793.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   df_copy.head().style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_cda2b">
#   <thead>
#     <tr>
#       <th id="T_cda2b_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_cda2b_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_cda2b_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_cda2b_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_cda2b_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_cda2b_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_cda2b_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_cda2b_level0_col7" class="col_heading level0 col7" >Workers</th>
# ...

# %% [markdown]
# #### 2 How can we set the caption / heading on the dataframe

# %%
df_copy.head().style.set_caption('India Census 2011 Dataset')
# Out:
# <style type="text/css">
# </style>
# <table id="T_83e0f">
#   <caption>India Census 2011 Dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83e0f_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_83e0f_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_83e0f_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_83e0f_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_83e0f_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_83e0f_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_83e0f_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_83e0f_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_83e0f_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# #### 3 Show the records related with the districts - New Delhi, Lucknow, Jaipur

# %%
df_copy[df_copy['District_name'].isin(['New Delhi','Lucknow','Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# #### 4 Calculate state-wise:

# %% [markdown]
# ##### A Total number of polulation

# %%
df_copy.groupby(['State_name']).Population.sum().sort_values(ascending=False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %% [markdown]
# ##### B Total no of polulation with different religions

# %%
df_copy.groupby(['State_name'])['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum()
# Out:
# /tmp/ipykernel_527/805639114.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_copy.groupby(['State_name'])['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum()
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# ARUNACHAL PRADESH               401876     27045      418732      3287
# ASSAM                         19180759  10679345     1165867     20672
# BIHAR                         86078686  17557809      129247     23779
# CHANDIGARH                      852574     51447        8720    138329
# CHHATTISGARH                  23819789    514998      490542     70036
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# ...

# %% [markdown]
# #### 5 How many male workers were there in Maharashtra state?

# %%
df_copy[df_copy['State_name'] == 'MAHARASHTRA'].Male_Workers.sum()
# Out:
# 331939875

# %% [markdown]
# #### 6 How to set a column as index of the dataframe?

# %%
df_copy.set_index('District_code')
# Out:
#                 State_name              District_name  Population    Male  \
# District_code
# 1              MAHARASHTRA                    Kupwara      870354  474190
# 2              MAHARASHTRA                     Badgam      753745  398041
# 3              MAHARASHTRA                Leh(Ladakh)      133487   78971
# 4              MAHARASHTRA                     Kargil      140802   77785
# 5              MAHARASHTRA                      Punch      476835  251899
# ...                    ...                        ...         ...     ...
# 636            MAHARASHTRA                       Mahe       41816   19143
# 637            MAHARASHTRA                   Karaikal      200222   97809
# 638            MAHARASHTRA                   Nicobars       36842   20727
# 639            MAHARASHTRA  North  AND Middle Andaman      105597   54861
# 640            MAHARASHTRA              South Andaman      238142  127283
#
# ...

# %% [markdown]
# #### 7a Add a Suffix to the column names

# %%
df_copy.add_suffix('_Suffix')
# Out:
#      District_code_Suffix State_name_Suffix       District_name_Suffix  \
# 0                       1       MAHARASHTRA                    Kupwara
# 1                       2       MAHARASHTRA                     Badgam
# 2                       3       MAHARASHTRA                Leh(Ladakh)
# 3                       4       MAHARASHTRA                     Kargil
# 4                       5       MAHARASHTRA                      Punch
# ..                    ...               ...                        ...
# 635                   636       MAHARASHTRA                       Mahe
# 636                   637       MAHARASHTRA                   Karaikal
# 637                   638       MAHARASHTRA                   Nicobars
# 638                   639       MAHARASHTRA  North  AND Middle Andaman
# 639                   640       MAHARASHTRA              South Andaman
#
#      Population_Suffix  Male_Suffix  Female_Suffix  Literate_Suffix  \
# ...

# %% [markdown]
# #### 7b Add a Prefix to the column names

# %%
df_copy.add_prefix('Prefix_')
# Out:
#      Prefix_District_code Prefix_State_name       Prefix_District_name  \
# 0                       1       MAHARASHTRA                    Kupwara
# 1                       2       MAHARASHTRA                     Badgam
# 2                       3       MAHARASHTRA                Leh(Ladakh)
# 3                       4       MAHARASHTRA                     Kargil
# 4                       5       MAHARASHTRA                      Punch
# ..                    ...               ...                        ...
# 635                   636       MAHARASHTRA                       Mahe
# 636                   637       MAHARASHTRA                   Karaikal
# 637                   638       MAHARASHTRA                   Nicobars
# 638                   639       MAHARASHTRA  North  AND Middle Andaman
# 639                   640       MAHARASHTRA              South Andaman
#
#      Prefix_Population  Prefix_Male  Prefix_Female  Prefix_Literate  \
# ...
