# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
import os

plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# ### Read the data

# %%
path = os.getcwd()
file = 'movies.csv'
full_path = os.path.join(path,file)

df = pd.read_csv(full_path)

# %% [markdown]
# ### Look the data

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df.shape
# Out:
# (7668, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df.describe(include=['O'])
# Out:
#                  name rating   genre                           released  \
# count            7668   7591    7668                               7666
# unique           7512     12      19                               3414
# top     Nobody's Fool      R  Comedy  February 14, 1986 (United States)
# freq                3   3697    2245                                  9
#
#            director       writer          star        country  \
# count          7668         7665          7667           7665
# unique         2949         4535          2814             59
# top     Woody Allen  Woody Allen  Nicolas Cage  United States
# freq             38           37            43           5475
#
#                    company
# count                 7651
# unique                2385
# top     Universal Pictures
# freq                   377

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %% [markdown]
# ### Cleaning the data

# %%
##Missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(f'{col} - {round(pct_missing*100,2)}')

df = df.dropna()
# Out:
# name - 0.0
# rating - 1.0
# genre - 0.0
# year - 0.0
# released - 0.03
# score - 0.04
# votes - 0.04
# director - 0.0
# writer - 0.04
# star - 0.01
# country - 0.04
# budget - 28.31
# gross - 2.46
# company - 0.22
# runtime - 0.05

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(f'{col} - {round(pct_missing*100,2)}')
# Out:
# name - 0.0
# rating - 0.0
# genre - 0.0
# year - 0.0
# released - 0.0
# score - 0.0
# votes - 0.0
# director - 0.0
# writer - 0.0
# star - 0.0
# country - 0.0
# budget - 0.0
# gross - 0.0
# company - 0.0
# runtime - 0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5421 entries, 0 to 7652
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5421 non-null   object
#  1   rating    5421 non-null   object
#  2   genre     5421 non-null   object
#  3   year      5421 non-null   int64
#  4   released  5421 non-null   object
#  5   score     5421 non-null   float64
#  6   votes     5421 non-null   float64
#  7   director  5421 non-null   object
#  8   writer    5421 non-null   object
#  9   star      5421 non-null   object
#  10  country   5421 non-null   object
#  11  budget    5421 non-null   float64
#  12  gross     5421 non-null   float64
#  13  company   5421 non-null   object
#  14  runtime   5421 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 677.6+ KB

# %%
### Change data type of columns

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
### Create correct year column

df['released year'] = df['released'].str.extract(pat='([0-9]{4})').astype(int)

# %%
df.sort_values('gross',inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %% [markdown]
# ### Data Analysis

# %%
### Budget high correlation
### Company high correlation

# %%
### Scatter plot with budget vs gross 

plt.scatter(x=df['budget'], y=df['gross'], color = '#EC7B96')
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.title('Budget vs Gross earnings')
plt.show()

# %%
### Plot budget vs gross using seaborn

sns.regplot(data=df, x='budget', y='gross', scatter_kws={'color':'#EC7B96'}, line_kws={'color':'#454AA5'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
### Looking correlation

df_corr = df.corr('pearson')
df_corr
# Out:
#                    year     score     votes    budget     gross   runtime  \
# year           1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score          0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes          0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget         0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross          0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime        0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# released year  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#                released year
# year                0.998726
# score               0.061923
# votes               0.203098
# budget              0.320312
# gross               0.268721
# runtime             0.075294
# released year       1.000000

# %%
print('Correlation budget vs gross 0.740247')
# Out:
# Correlation budget vs gross 0.740247

# %%
sns.heatmap(data=df_corr,annot=True,linecolor='black',linewidths=5)
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.title('Budget vs Gross earnings')
plt.show()

# %%
### Looks at company

df_numerized = df

for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype) =='object':
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1     3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2     3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3      204       4      4  1980      1127    7.7   221000.0       889    1413
# 4      732       6      4  1980      1170    7.3   108000.0       719     351
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7648   415       6      0  2020       904    6.6   140000.0        16    2390
# 7649  3556       4      0  2020       713    6.5   102000.0       852    2309
# 7650  1153       4      1  2020       904    5.6    53000.0      1809    2827
# 7651  3978       4      1  2020       758    6.8    42000.0       294    2091
# 7652  4090       3      0  2020       370    6.8     3700.0       746    1184
#
# ...

# %%
df_numerized_corr = df_numerized.corr('pearson')
df_numerized_corr
# Out:
#                    name    rating     genre      year  released     score  \
# name           1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating        -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre          0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year           0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released      -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# ...                 ...       ...       ...       ...       ...       ...
# budget         0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross          0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# company        0.021697 -0.092357 -0.071334 -0.014333 -0.002407  0.020656
# runtime        0.010850  0.140792 -0.059237  0.075077  0.008975  0.414068
# released year  0.025542  0.022021 -0.069147  0.998726 -0.005989  0.061923
#
#                   votes  director    writer      star   country    budget  \
# ...

# %%
sns.heatmap(data=df_numerized_corr,annot=True,linecolor='black',linewidths=5)
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.title('Correlation matric for numeric features')
plt.show()

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre          budget          -0.368523
# budget         genre           -0.368523
# gross          genre           -0.244101
# genre          gross           -0.244101
# rating         budget          -0.203946
#                                   ...
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# released year  released year    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr = high_corr[(high_corr) != 1]
high_corr = high_corr.sort_values(ascending=False)
high_corr
# Out:
# year           released year    0.998726
# released year  year             0.998726
# gross          budget           0.740247
# budget         gross            0.740247
# gross          votes            0.614751
# votes          gross            0.614751
# dtype: float64

# %% [markdown]
# ### Budget and votes have the highest correlation to gross earninghs
# ### Companys has low correlation
